# %% [markdown]
# # Practice Problem Set 1
#
# For practice creating functions, build your own functions to solve for the volume of a pyramid, cylinder, and torus. The formulas to solve the volume of these shapes are shown below:
#
#
# Pyramid: $V = \frac{lwh}{3}$ ![Screen%20Shot%202020-03-25%20at%201.30.25%20PM.png](attachment:Screen%20Shot%202020-03-25%20at%201.30.25%20PM.png)
# Cylinder: $V = \pi r^2h$ ![Screen%20Shot%202020-03-25%20at%201.32.39%20PM.png](attachment:Screen%20Shot%202020-03-25%20at%201.32.39%20PM.png)
# Torus: $V = (\pi r^2)(2\pi R)$ ![Screen%20Shot%202020-03-25%20at%201.33.01%20PM.png](attachment:Screen%20Shot%202020-03-25%20at%201.33.01%20PM.png)

# %%
def pyramid(l,w,h):
    return

# %%
pyramid(3,6,5)

# %%
def cylinder():
    return volume

# %% [markdown]
# Check your cylinder function by solving for the volume of a cylinder with radius of 2 and a height of 12.

# %%
def torus():
    return volume

# %% [markdown]
# Check your torus function by solving for the volume of a cylinder with a minor radius (r) of 3 and a major radius (R) of 8.
